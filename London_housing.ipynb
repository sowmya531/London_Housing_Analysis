# %%
import pandas as pd

# %%
house=pd.read_csv(r"C:\Users\Sowmya Kondapalli\Downloads\5. London Housing Data.csv")

# %%
house
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
#count of all non null values
house.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
house.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
#to visualize the null values in the dataset
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(house.isnull())
# Out:
# <Axes: >

# %%
#Q. 1) Convert the Datatype of 'Date' column to Date-Time format.
#house.head(10)
#house.dtypes
house.date=pd.to_datetime(house.date)

# %%
house.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
#Q. 2) Add a new column ''year'' in the dataframe, which contains years only
house['Year']=house.date.dt.year

# %%
#new column year is added 
house.head(10)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
# 5 1995-06-01  city of london          94901  E09000001         17.0
# 6 1995-07-01  city of london         110128  E09000001         13.0
# 7 1995-08-01  city of london         112329  E09000001         14.0
# 8 1995-09-01  city of london         104473  E09000001         17.0
# 9 1995-10-01  city of london         108038  E09000001         14.0
#
#    no_of_crimes  Year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995
# 5           NaN  1995
# 6           NaN  1995
# 7           NaN  1995
# ...

# %%
house
# Out:
#             date            area  month  average_price       code  \
# 0     1995-01-01  city of london      1          91449  E09000001
# 1     1995-02-01  city of london      2          82203  E09000001
# 2     1995-03-01  city of london      3          79121  E09000001
# 3     1995-04-01  city of london      4          77101  E09000001
# 4     1995-05-01  city of london      5          84409  E09000001
# ...          ...             ...    ...            ...        ...
# 13544 2019-09-01         england      9         249942  E92000001
# 13545 2019-10-01         england     10         249376  E92000001
# 13546 2019-11-01         england     11         248515  E92000001
# 13547 2019-12-01         england     12         250410  E92000001
# 13548 2020-01-01         england      1         247355  E92000001
#
#        houses_sold  no_of_crimes  Year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %%
house

# %%
#(2.B) Add a new column ''month'' as 2nd column in the dataframe, which contains month only
house.insert(1,'months',house.date.dt.month)# to check month is added in 2nd column before tried with month col  name but no result 
#later tried with months col name

# %%
house
# Out:
#             date  months            area  average_price       code  \
# 0     1995-01-01       1  city of london          91449  E09000001
# 1     1995-02-01       2  city of london          82203  E09000001
# 2     1995-03-01       3  city of london          79121  E09000001
# 3     1995-04-01       4  city of london          77101  E09000001
# 4     1995-05-01       5  city of london          84409  E09000001
# ...          ...     ...             ...            ...        ...
# 13544 2019-09-01       9         england         249942  E92000001
# 13545 2019-10-01      10         england         249376  E92000001
# 13546 2019-11-01      11         england         248515  E92000001
# 13547 2019-12-01      12         england         250410  E92000001
# 13548 2020-01-01       1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  Year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %%
#Q. 3) Remove the columns 'year' and 'month' from the dataframe
#house.columns
house.drop('months',axis=1,inplace=True)

# %%
house.columns
# Out:
# Index(['date', 'months', 'area', 'average_price', 'code', 'houses_sold',
#        'no_of_crimes', 'Year'],
#       dtype='object')

# %%
house
# Out:
#             date  months            area  average_price       code  \
# 0     1995-01-01       1  city of london          91449  E09000001
# 1     1995-02-01       2  city of london          82203  E09000001
# 2     1995-03-01       3  city of london          79121  E09000001
# 3     1995-04-01       4  city of london          77101  E09000001
# 4     1995-05-01       5  city of london          84409  E09000001
# ...          ...     ...             ...            ...        ...
# 13544 2019-09-01       9         england         249942  E92000001
# 13545 2019-10-01      10         england         249376  E92000001
# 13546 2019-11-01      11         england         248515  E92000001
# 13547 2019-12-01      12         england         250410  E92000001
# 13548 2020-01-01       1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  Year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %%
house.drop(['Year', 'months'], axis=1, inplace=True)

# %%
house
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
##Q. 4) Show all the records where 'No. of Crimes' is 0. And, how many such records are there ?
#house.head(2)
house[house.no_of_crimes == 0].shape[0]
# Out:
# 104

# %%
#Q. 5) What is the maximum & minimum 'average_price' per year in England ?
house[house.area == 'england'].groupby('Year')['average_price'].agg(['max', 'min'])
# Out:
#          max     min
# Year
# 1995   53901   52788
# 1996   55755   52333
# 1997   61564   55789
# 1998   65743   61659
# 1999   75071   65522
# 2000   84191   75219
# 2001   95992   84245
# 2002  119982   96215
# 2003  138985  121610
# 2004  160330  139719
# 2005  167244  158572
# 2006  182031  166544
# 2007  194764  181824
# 2008  191750  165795
# 2009  174136  159340
# 2010  180807  174458
# 2011  177335  173046
# 2012  180129  174161
# 2013  188544  176816
# 2014  203639  188265
# 2015  219582  202856
# 2016  231922  220361
# 2017  242628  231593
# 2018  248620  240428
# 2019  250410  243281
# 2020  247355  247355

# %%
house.area.unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
#Q. 6) What is the Maximum & Minimum No. of Crimes recorded per area ?
house.groupby('area')['no_of_crimes'].agg(['max','min'])
# Out:
#                            max     min
# area
# barking and dagenham    2049.0  1217.0
# barnet                  2893.0  1703.0
# bexley                  1914.0   860.0
# brent                   2937.0  1850.0
# bromley                 2637.0  1441.0
# camden                  4558.0  2079.0
# city of london            10.0     0.0
# croydon                 3263.0  2031.0
# ealing                  3401.0  1871.0
# east midlands              NaN     NaN
# east of england            NaN     NaN
# enfield                 2798.0  1635.0
# england                    NaN     NaN
# greenwich               2853.0  1513.0
# hackney                 3466.0  1870.0
# hammersmith and fulham  2645.0  1323.0
# haringey                3199.0  1536.0
# harrow                  1763.0   937.0
# havering                1956.0  1130.0
# hillingdon              2819.0  1445.0
# hounslow                2817.0  1529.0
# inner london               NaN     NaN
# islington               3384.0  1871.0
# ...

# %%
#Q. 7) Show the total count of records of each area, where average price is less than 100000.
house[house.average_price<100000].groupby('area')['average_price'].count()
# Out:
# area
# barking and dagenham     85
# barnet                   25
# bexley                   64
# brent                    40
# bromley                  33
# city of london           11
# croydon                  57
# ealing                   31
# east midlands            96
# east of england          76
# enfield                  54
# england                  87
# greenwich                59
# hackney                  53
# haringey                 33
# harrow                   30
# havering                 60
# hillingdon               44
# hounslow                 41
# inner london             31
# islington                19
# kingston upon thames     30
# lambeth                  41
# lewisham                 62
# london                   39
# merton                   35
# newham                   72
# north east              112
# north west              111
# outer london             46
# redbridge                52
# south east               59
# south west               78
# ...
